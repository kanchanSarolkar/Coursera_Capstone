# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Postcode"
# 2:"Borough"
# 3:"Neighbourhood
# "

# %%
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [288, 288, 288]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

#Remove \n from the dataframe
df = df.replace('\n',' ', regex=True)
df
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                        Neighbourhood\n
# 0                                        Not assigned
# 1                                        Not assigned
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                                        Harbourfront
# 5                                         Regent Park
# 6                                    Lawrence Heights
# 7                                      Lawrence Manor
# 8                                        Not assigned
# 9                                        Not assigned
# 10                                   Islington Avenue
# 11                                              Rouge
# 12                                            Malvern
# 13                                       Not assigned
# 14                                    Don Mills North
# 15                                   Woodbine Gardens
# 16                                      Parkview Hill
# 17                                            Ryerson
# 18                                    Garden District
# 19                                          Glencairn
# 20                                       Not assigned
# 21                                       Not assigned
# 22                                         Cloverdale
# 23                                          Islington
# 24                                       Martin Grove
# 25                                   Princess Gardens
# 26                                    West Deane Park
# 27                                     Highland Creek
# 28                                         Rouge Hill
# 29                                         Port Union
# ..                                                 ...
# 258                                      Not assigned
# 259                                      Not assigned
# 260                                      Not assigned
# 261                                      Not assigned
# 262                              Church and Wellesley
# 263                                      Not assigned
# 264                                      Not assigned
# 265  Business Reply Mail Processing Centre 969 East...
# 266                                        Humber Bay
# 267                                  King's Mill Park
# 268                          Kingsway Park South East
# 269                                         Mimico NE
# 270                                    Old Mill South
# 271                                The Queensway East
# 272                             Royal York South East
# 273                                          Sunnylea
# 274                                      Not assigned
# 275                                      Not assigned
# 276                                      Not assigned
# 277                                      Not assigned
# 278                                      Not assigned
# 279                                      Not assigned
# 280                                      Not assigned
# 281                                      Not assigned
# 282                          Kingsway Park South West
# 283                                         Mimico NW
# 284                                The Queensway West
# 285                             Royal York South West
# 286                                    South of Bloor
# 287                                      Not assigned
#
# [288 rows x 3 columns]

# %%
df.columns=['Postal Code','Borough','Neighbourhood']
#Grouping by postal code and aggregating neighbourhoods
df=df.groupby("Postal Code").agg(lambda x:','.join(set(x)))

# %%
#Assigning 'not assigned' neighbourhood same as borough
df.loc[df['Neighbourhood'].isin( ["Not assigned",'Neighbourhood'])]=df.loc[df['Neighbourhood'].isin( ["Not assigned",'Borough'])]

# %%
#Ignoring not assigned boroughs
df = df.loc[df['Borough'] != 'Not assigned']
df
# Out:
#                       Borough  \
# Postal Code
# M1B               Scarborough
# M1C               Scarborough
# M1E               Scarborough
# M1G               Scarborough
# M1H               Scarborough
# M1J               Scarborough
# M1K               Scarborough
# M1L               Scarborough
# M1M               Scarborough
# M1N               Scarborough
# M1P               Scarborough
# M1R               Scarborough
# M1S               Scarborough
# M1T               Scarborough
# M1V               Scarborough
# M1W               Scarborough
# M1X               Scarborough
# M2H                North York
# M2J                North York
# M2K                North York
# M2L                North York
# M2M                North York
# M2N                North York
# M2P                North York
# M2R                North York
# M3A                North York
# M3B                North York
# M3C                North York
# M3H                North York
# M3J                North York
# ...                       ...
# M6C                      York
# M6E                      York
# M6G          Downtown Toronto
# M6H              West Toronto
# M6J              West Toronto
# M6K              West Toronto
# M6L                North York
# M6M                      York
# M6N                      York
# M6P              West Toronto
# M6R              West Toronto
# M6S              West Toronto
# M7A              Queen's Park
# M7R               Mississauga
# M7Y              East Toronto
# M8V                 Etobicoke
# M8W                 Etobicoke
# M8X                 Etobicoke
# M8Y                 Etobicoke
# M8Z                 Etobicoke
# M9A                 Etobicoke
# M9B                 Etobicoke
# M9C                 Etobicoke
# M9L                North York
# M9M                North York
# M9N                      York
# M9P                 Etobicoke
# M9R                 Etobicoke
# M9V                 Etobicoke
# M9W                 Etobicoke
#
#                                                  Neighbourhood
# Postal Code
# M1B                                            Malvern ,Rouge
# M1C                    Port Union ,Rouge Hill ,Highland Creek
# M1E                         West Hill ,Guildwood ,Morningside
# M1G                                                    Woburn
# M1H                                                 Cedarbrae
# M1J                                       Scarborough Village
# M1K               Kennedy Park ,East Birchmount Park ,Ionview
# M1L                           Clairlea ,Golden Mile ,Oakridge
# M1M           Cliffcrest ,Scarborough Village West ,Cliffside
# M1N                               Birch Cliff ,Cliffside West
# M1P          Wexford Heights ,Dorset Park ,Scarborough Town...
# M1R                                         Maryvale ,Wexford
# M1S                                                 Agincourt
# M1T                   Sullivan ,Tam O'Shanter ,Clarks Corners
# M1V          Steeles East ,L'Amoreaux East ,Agincourt North...
# M1W                                           L'Amoreaux West
# M1X                                               Upper Rouge
# M2H                                         Hillcrest Village
# M2J                              Henry Farm ,Oriole ,Fairview
# M2K                                           Bayview Village
# M2L                                  York Mills ,Silver Hills
# M2M                                   Willowdale ,Newtonbrook
# M2N                                          Willowdale South
# M2P                                           York Mills West
# M2R                                           Willowdale West
# M3A                                                 Parkwoods
# M3B                                           Don Mills North
# M3C                          Don Mills South ,Flemingdon Park
# M3H           Bathurst Manor ,Wilson Heights ,Downsview North
# M3J                           York University ,Northwood Park
# ...                                                        ...
# M6C                                        Humewood-Cedarvale
# M6E                                       Caledonia-Fairbanks
# M6G                                                  Christie
# M6H                              Dufferin ,Dovercourt Village
# M6J                                  Little Portugal ,Trinity
# M6K              Exhibition Place ,Brockton ,Parkdale Village
# M6L                        Upwood Park ,Downsview ,North Park
# M6M            Del Ray ,Silverthorn ,Mount Dennis ,Keelesdale
# M6N                             Runnymede ,The Junction North
# M6P                             The Junction South ,High Park
# M6R                                    Parkdale ,Roncesvalles
# M6S                                        Runnymede ,Swansea
# M7A                                              Not assigned
# M7R                     Canada Post Gateway Processing Centre
# M7Y          Business Reply Mail Processing Centre 969 East...
# M8V              Mimico South ,New Toronto ,Humber Bay Shores
# M8W                                    Alderwood ,Long Branch
# M8X             The Kingsway ,Montgomery Road ,Old Mill North
# M8Y          Mimico NE ,Royal York South East ,Humber Bay ,...
# M8Z          South of Bloor ,Mimico NW ,The Queensway West ...
# M9A                                          Islington Avenue
# M9B          Cloverdale ,Islington ,West Deane Park ,Martin...
# M9C          Bloordale Gardens ,Markland Wood ,Eringate ,Ol...
# M9L                                             Humber Summit
# M9M                                          Emery ,Humberlea
# M9N                                                    Weston
# M9P                                                 Westmount
# M9R          Kingsview Village ,Martin Grove Gardens ,St. P...
# M9V          Mount Olive ,Humbergate ,Silverstone ,South St...
# M9W                                                 Northwest
#
# [103 rows x 2 columns]

# %%
#Resetting index
df.reset_index()
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A      Queen's Park
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                      Malvern ,Rouge
# 1              Port Union ,Rouge Hill ,Highland Creek
# 2                   West Hill ,Guildwood ,Morningside
# 3                                              Woburn
# 4                                           Cedarbrae
# 5                                 Scarborough Village
# 6         Kennedy Park ,East Birchmount Park ,Ionview
# 7                     Clairlea ,Golden Mile ,Oakridge
# 8     Cliffcrest ,Scarborough Village West ,Cliffside
# 9                         Birch Cliff ,Cliffside West
# 10   Wexford Heights ,Dorset Park ,Scarborough Town...
# 11                                  Maryvale ,Wexford
# 12                                          Agincourt
# 13            Sullivan ,Tam O'Shanter ,Clarks Corners
# 14   Steeles East ,L'Amoreaux East ,Agincourt North...
# 15                                    L'Amoreaux West
# 16                                        Upper Rouge
# 17                                  Hillcrest Village
# 18                       Henry Farm ,Oriole ,Fairview
# 19                                    Bayview Village
# 20                           York Mills ,Silver Hills
# 21                            Willowdale ,Newtonbrook
# 22                                   Willowdale South
# 23                                    York Mills West
# 24                                    Willowdale West
# 25                                          Parkwoods
# 26                                    Don Mills North
# 27                   Don Mills South ,Flemingdon Park
# 28    Bathurst Manor ,Wilson Heights ,Downsview North
# 29                    York University ,Northwood Park
# ..                                                 ...
# 73                                 Humewood-Cedarvale
# 74                                Caledonia-Fairbanks
# 75                                           Christie
# 76                       Dufferin ,Dovercourt Village
# 77                           Little Portugal ,Trinity
# 78       Exhibition Place ,Brockton ,Parkdale Village
# 79                 Upwood Park ,Downsview ,North Park
# 80     Del Ray ,Silverthorn ,Mount Dennis ,Keelesdale
# 81                      Runnymede ,The Junction North
# 82                      The Junction South ,High Park
# 83                             Parkdale ,Roncesvalles
# 84                                 Runnymede ,Swansea
# 85                                       Not assigned
# 86              Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 East...
# 88       Mimico South ,New Toronto ,Humber Bay Shores
# 89                             Alderwood ,Long Branch
# 90      The Kingsway ,Montgomery Road ,Old Mill North
# 91   Mimico NE ,Royal York South East ,Humber Bay ,...
# 92   South of Bloor ,Mimico NW ,The Queensway West ...
# 93                                   Islington Avenue
# 94   Cloverdale ,Islington ,West Deane Park ,Martin...
# 95   Bloordale Gardens ,Markland Wood ,Eringate ,Ol...
# 96                                      Humber Summit
# 97                                   Emery ,Humberlea
# 98                                             Weston
# 99                                          Westmount
# 100  Kingsview Village ,Martin Grove Gardens ,St. P...
# 101  Mount Olive ,Humbergate ,Silverstone ,South St...
# 102                                         Northwest
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 2)
